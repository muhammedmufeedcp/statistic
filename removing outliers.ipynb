# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# sample dataset
data = [7, 15, 36, 40, 41, 42, 47, 49]

# %%
# calculate q1, q2, and q3
q1 = np.quantile(data, 0.25)
q2 = np.quantile(data, 0.50)
q3 = np.quantile(data, 0.75)

q1,q2,q3
# Out:
# (30.75, 40.5, 43.25)

# %%
# calculate the iqr
iqr = q3-q1
iqr
# Out:
# 12.5

# %% [markdown]
# #boxplot

# %%
# boxplot to vishulize quartiles and iqr

plt.boxplot(data)
plt.title( 'boxplot of data' )
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
# claculate outlier boundaries
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

print("lower_bound :", lower_bound)
print("upper_bound :", upper_bound)
# Out:
# lower_bound : 12.0
# upper_bound : 62.0

# %% [markdown]
# the whiskers extend to the most extreme values within thes bounds:
#   .lower wishker : the smallest data point graete or equal to 27.75, which is
#   .upper the whishker: the largest data point less than or equal to 51.75.which is 49

# %%
# Identify outliers

outliers = [x for x in data if x < lower_bound or x > upper_bound]

# Any data point below the lower Bound or above the Upper Bound is considered an outlier.

# Output the results
outliers
# Out:
# [7]
